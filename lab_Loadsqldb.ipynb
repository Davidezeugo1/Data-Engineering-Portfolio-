# %%
import pandas as pd
import mysql.connector
import sqlalchemy
from sqlalchemy import create_engine

# %%
conn= mysql.connector.connect( 
    username='root',
    password='Davvysql#1',
    host='localhost',
    database='sqldb',
    ssl_disabled=True
)

print("Connected using mysql.connector:", conn)
# Out:
# Connected using mysql.connector: <mysql.connector.connection.MySQLConnection object at 0x0000014B526C7CB0>

# %%
cursor = conn.cursor() 
cursor.execute("SHOW DATABASES;")
print("Databases:", cursor.fetchall())
# Out:
# Databases: [('information_schema',), ('mysql',), ('performance_schema',), ('sqldb',), ('sys',)]

# %%
cursor.execute("use sqldb;")

# %%
cursor.execute('show tables')
print(cursor.fetchall())
# Out:
# [('dimcategory',), ('dimcountry',), ('dimdate',), ('factsales',)]

# %%
dimcatedata=pd.read_csv(r'C:\Users\dezeu\Downloads\DimCategory.csv',  index_col=False) 
dimcountrydata=pd.read_csv(r'C:\Users\dezeu\Downloads\DimCountry.csv',  index_col=False) 
dimdatedata=pd.read_csv(r'C:\Users\dezeu\Downloads\DimDate.csv',  index_col=False) 
factsalesdata =pd.read_csv(r'C:\Users\dezeu\Downloads\FactSales.csv',  index_col=False) 
print ("All csv files converted to df!")
# Out:
# All csv files converted to df!

# %%
e = create_engine('mysql+pymysql://root:Davvysql#1@localhost:3306/sqldb')

dimcatedata.to_sql('dimcategory',e, if_exists='replace', index=False) 
dimcountrydata.to_sql('dimcountry',e, if_exists='replace', index=False) 
dimdatedata.to_sql('dimdate',e, if_exists='replace', index=False) 
factsalesdata.to_sql('factsales',e, if_exists='replace', index=False) 

df_check = pd.read_sql("SELECT * FROM DimCategory LIMIT 5;", con=e)
print("Preview from DB:")
print(df_check)

df_check2 = pd.read_sql("SELECT * FROM DimCountry LIMIT 5;", con=e)
print("Preview from DB:")
print(df_check2)

df_check3 = pd.read_sql("SELECT * FROM Dimdate LIMIT 5;", con=e)
print("Preview from DB:")
print(df_check3)

df_check4 = pd.read_sql("SELECT * FROM Factsales LIMIT 5;", con=e)
print("Preview from DB:")
print(df_check4)
# Out:
# Preview from DB:
#    categoryid     category
# 0           1  Electronics
# 1           2        Books
# 2           3         Toys
# 3           4       Sports
# 4           5     Software
# Preview from DB:
#    countryid     country
# 0          1   Argentina
# 1          2   Australia
# 2          3     Austria
# 3          4  Azerbaijan
# 4          5     Belgium
# Preview from DB:
#    dateid        date  Year  Quarter QuarterName  Month Monthname  Day  \
# 0       1  2019-01-01  2019        1          Q1      1   January    1
# 1       2  2019-01-02  2019        1          Q1      1   January    2
# 2       3  2019-01-03  2019        1          Q1      1   January    3
# 3       4  2019-01-04  2019        1          Q1      1   January    4
# 4       5  2019-01-05  2019        1          Q1      1   January    5
#
#    Weekday WeekdayName
# 0        3     Tuesday
# 1        4   Wednesday
# 2        5    Thursday
# 3        6      Friday
# 4        7    Saturday
# ...

# %%
cursor.close()
print('Cursor closed')

conn.close()
print('Connection closed')
# Out:
# Cursor closed
# Connection closed
