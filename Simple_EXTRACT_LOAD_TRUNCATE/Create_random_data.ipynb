# %%
import pandas as pd
import numpy as np


def get_dataset(size):
    # Create Fake Dataset
    df = pd.DataFrame()
    df['size'] = np.random.choice(['big','medium','small'], size)
    df['age'] = np.random.randint(1, 50, size)
    df['team'] = np.random.choice(['red','blue','yellow','green'], size)
    df['win'] = np.random.choice(['yes','no'], size)
    dates = pd.date_range('2020-01-01', '2022-12-31')
    df['date'] = np.random.choice(dates, size)
    df['prob'] = np.random.uniform(0, 1, size)
    return df

def set_dtypes(df):
    df['size'] = df['size'].astype('category')
    df['team'] = df['team'].astype('category')
    df['age'] = df['age'].astype('int16')
    df['win'] = df['win'].map({'yes':True, 'no': False})
    df['prob'] = df['prob'].astype('float32')
    return df


print('Reading and writing CSV')
df = get_dataset(10)
df = set_dtypes(df)
# %time df.to_csv('test.csv')
# %time df_csv = pd.read_csv('test.csv')

print('Reading and writing Pickle')
df = get_dataset(10)
df = set_dtypes(df)
# %time df.to_pickle('test.pickle')
# %time df_pickle = pd.read_pickle('test.pickle')
# Out:
# Reading and writing CSV
# CPU times: total: 26.2 s
# Wall time: 27.3 s
# CPU times: total: 7.17 s
# Wall time: 7.71 s
# Reading and writing Pickle
# CPU times: total: 78.1 ms
# Wall time: 119 ms
# CPU times: total: 46.9 ms
# Wall time: 59.8 ms
# Reading and writing Feather
# CPU times: total: 0 ns
# Wall time: 16.1 ms
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\dezeu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\dezeu\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1397     name = _resolve_name(name, package, level)
# -> 1398 return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1370     if module is _NEEDS_LOADING:
# -> 1371         return _find_and_load_unlocked(name, import_)
#    1373 # Optimization: only call _bootstrap._lock_unlock_module() if
#    1374 # module.__spec__._initializing is True.
#    1375 # NOTE: because of this, initializing must be set *before*
#    1376 # putting the new module in sys.modules.
#
# File <frozen importlib._bootstrap>:1335, in _find_and_load_unlocked(name, import_)
#    1334 if spec is None:
# -> 1335     raise ModuleNotFoundError(f'{_ERR_MSG_PREFIX}{name!r}', name=name)
#    1336 else:
#
# ModuleNotFoundError: No module named 'pyarrow'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 39
#      37 df = get_dataset(5_000_000)
#      38 df = set_dtypes(df)
# ---> 39 get_ipython().run_line_magic('time', "df.to_feather('test.feather')")
#      40 get_ipython().run_line_magic('time', "df_feather = pd.read_feather('test.feather')")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Roaming\Python\Python314\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File ~\AppData\Roaming\Python\Python314\site-packages\IPython\core\magics\execution.py:1402, in ExecutionMagics.time(self, line, cell, local_ns)
#    1400 st = clock2()
#    1401 try:
# -> 1402     out = eval(code, glob, local_ns)
#    1403 except KeyboardInterrupt as e:
#    1404     captured_exception = e
#
# File <timed eval>:1
#
# File c:\Users\dezeu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:2949, in DataFrame.to_feather(self, path, **kwargs)
#    2921 """
#    2922 Write a DataFrame to the binary Feather format.
#    2923
#    (...)   2945 >>> df.to_feather("file.feather")  # doctest: +SKIP
#    2946 """
#    2947 from pandas.io.feather_format import to_feather
# -> 2949 to_feather(self, path, **kwargs)
#
# File c:\Users\dezeu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\feather_format.py:56, in to_feather(df, path, storage_options, **kwargs)
#      37 @doc(storage_options=_shared_docs["storage_options"])
#      38 def to_feather(
#      39     df: DataFrame,
#    (...)     42     **kwargs: Any,
#      43 ) -> None:
#      44     """
#      45     Write a DataFrame to the binary Feather format.
#      46
#    (...)     54
#      55     """
# ---> 56     import_optional_dependency("pyarrow")
#      57     from pyarrow import feather
#      59     if not isinstance(df, DataFrame):
#
# File c:\Users\dezeu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'pyarrow'.  Use pip or conda to install pyarrow.
